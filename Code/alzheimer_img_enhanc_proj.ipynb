# %%
import numpy as np
import pandas as pd
import seaborn as sns
import tensorflow as tf
from tensorflow import keras
import matplotlib.pyplot as plt
import os
import cv2

# %%
from os import listdir
 
# get the path/directory
classes = ['MildDemented', 'ModerateDemented', 'NonDemented', 'VeryMildDemented']
for cl in classes:
    folder_dir = "C:/Users/dell/Documents/VIT/6th_Semester/Medical_Image_Analysis_CSE3042/Project/Alzheimer_s_Dataset/train/" + cl
    print(folder_dir)
    count = 0
    for images in os.listdir(folder_dir):
        # check if the image ends with jpg
        if (images.endswith(".jpg")):
            # frame_normed = 255 * (image - image.min()) / (image.max() - image.min())
            # frame_normed = np.array(frame_normed, np.int)
            # print(folder_dir + "/" + images)
            img = cv2.imread(folder_dir + "/" + images)
            gray_img=cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
            # print(gray_img)
            gray_img_eqhist = cv2.equalizeHist(gray_img)
            target_dir = "C:/Users/dell/Documents/VIT/6th_Semester/Medical_Image_Analysis_CSE3042/Project/Alzheimer_s_Dataset/train_enhanced/" + cl 
            # print("target directory")
            # print(target_dir)
            cv2.imwrite(os.path.join(target_dir , 'img{0}.jpg'.format(count)), gray_img_eqhist)
            count += 1
# Out:
# C:/Users/dell/Documents/VIT/6th_Semester/Medical_Image_Analysis_CSE3042/Project/Alzheimer_s_Dataset/train/MildDemented
# C:/Users/dell/Documents/VIT/6th_Semester/Medical_Image_Analysis_CSE3042/Project/Alzheimer_s_Dataset/train/ModerateDemented
# C:/Users/dell/Documents/VIT/6th_Semester/Medical_Image_Analysis_CSE3042/Project/Alzheimer_s_Dataset/train/NonDemented
# C:/Users/dell/Documents/VIT/6th_Semester/Medical_Image_Analysis_CSE3042/Project/Alzheimer_s_Dataset/train/VeryMildDemented

# %% [markdown]
# ## Gaussian Filter

# %%
# get the path/directory
classes = ['MildDemented', 'ModerateDemented', 'NonDemented', 'VeryMildDemented']
for cl in classes:
    folder_dir = "C:/Users/dell/Documents/VIT/6th_Semester/Medical_Image_Analysis_CSE3042/Project/Alzheimer_s_Dataset/dataset_reduced_trainOrg/" + cl
    print(folder_dir)
    count = 0
    for images in os.listdir(folder_dir):
        # check if the image ends with jpg
        if (images.endswith(".jpg")):
            # print(folder_dir + "/" + images)
            img = cv2.imread(folder_dir + "/" + images)
            # print(gray_img)
            gray_img_eqhist = cv2.GaussianBlur(img, (9, 9),0)
            target_dir = "C:/Users/dell/Documents/VIT/6th_Semester/Medical_Image_Analysis_CSE3042/Project/Alzheimer_s_Dataset/dataset_reduced_gauss/" + cl 
            # print("target directory")
            # print(target_dir)
            cv2.imwrite(os.path.join(target_dir , 'img{0}.jpg'.format(count)), gray_img_eqhist)
            count += 1
# Out:
# C:/Users/dell/Documents/VIT/6th_Semester/Medical_Image_Analysis_CSE3042/Project/Alzheimer_s_Dataset/dataset_reduced_trainOrg/MildDemented
# C:/Users/dell/Documents/VIT/6th_Semester/Medical_Image_Analysis_CSE3042/Project/Alzheimer_s_Dataset/dataset_reduced_trainOrg/ModerateDemented
# C:/Users/dell/Documents/VIT/6th_Semester/Medical_Image_Analysis_CSE3042/Project/Alzheimer_s_Dataset/dataset_reduced_trainOrg/NonDemented
# C:/Users/dell/Documents/VIT/6th_Semester/Medical_Image_Analysis_CSE3042/Project/Alzheimer_s_Dataset/dataset_reduced_trainOrg/VeryMildDemented

# %% [markdown]
# ## Unsharp Filter

# %%
# get the path/directory
from PIL import ImageFilter
import numpy
classes = ['MildDemented', 'ModerateDemented', 'NonDemented', 'VeryMildDemented']
for cl in classes:
    folder_dir = "C:/Users/dell/Documents/VIT/6th_Semester/Medical_Image_Analysis_CSE3042/Project/Alzheimer_s_Dataset/dataset_reduced_trainOrg/" + cl
    # print(folder_dir)
    count = 0
    for images in os.listdir(folder_dir):
        # check if the image ends with jpg
        if (images.endswith(".jpg")):
            print(folder_dir + "/" + images)
            img = cv2.imread(folder_dir + "/" + images)
            # print(gray_img)
            image = Image.fromarray(img.astype('uint8'))
            new_image = image.filter(ImageFilter.UnsharpMask(radius=2, percent=150))
            newImg = numpy.array(new_image)
            print(type(new_image))
            target_dir = "C:/Users/dell/Documents/VIT/6th_Semester/Medical_Image_Analysis_CSE3042/Project/Alzheimer_s_Dataset/dataset_reduced_unsharp/" + cl 
            # print("target directory")
            # print(target_dir)
            cv2.imwrite(os.path.join(target_dir , 'img{0}.jpg'.format(count)), newImg)
            count += 1
# Out:
# C:/Users/dell/Documents/VIT/6th_Semester/Medical_Image_Analysis_CSE3042/Project/Alzheimer_s_Dataset/dataset_reduced_trainOrg/MildDemented/mildDem0.jpg
# <class 'PIL.Image.Image'>
# C:/Users/dell/Documents/VIT/6th_Semester/Medical_Image_Analysis_CSE3042/Project/Alzheimer_s_Dataset/dataset_reduced_trainOrg/MildDemented/mildDem1.jpg
# <class 'PIL.Image.Image'>
# C:/Users/dell/Documents/VIT/6th_Semester/Medical_Image_Analysis_CSE3042/Project/Alzheimer_s_Dataset/dataset_reduced_trainOrg/MildDemented/mildDem10.jpg
# <class 'PIL.Image.Image'>
# C:/Users/dell/Documents/VIT/6th_Semester/Medical_Image_Analysis_CSE3042/Project/Alzheimer_s_Dataset/dataset_reduced_trainOrg/MildDemented/mildDem100.jpg
# <class 'PIL.Image.Image'>
# C:/Users/dell/Documents/VIT/6th_Semester/Medical_Image_Analysis_CSE3042/Project/Alzheimer_s_Dataset/dataset_reduced_trainOrg/MildDemented/mildDem101.jpg
# <class 'PIL.Image.Image'>
# ...
